# %% [markdown]
# <a href="https://colab.research.google.com/github/BadriMounika/Python-Pandas/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Loading data into Pandas**

# %%
import pandas as pd
df=pd.read_csv('Pokemon.csv.zip')
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.tail(5)
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %%
df1=pd.read_excel('Pokemon.xlsx')
df1
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df1.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df2=pd.read_csv('Pokemon.txt',delimiter='\t')
df2.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# # **Reading Data in Pandas**

# %%
#Read Headers
print(df.columns)

#Read each column
print(df['Name'][0:5])
print(df[['Name','Type 1']])

#Read each row
print(df.iloc[1:4])
for index,row in df.iterrows():
  print(index,row['Name'][0:5])
df.loc[df['Type 1']=="Grass"]

#Read a specific location(R,C)
print(df.iloc[2,1])
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object
#                       Name   Type 1
# 0                Bulbasaur    Grass
# 1                  Ivysaur    Grass
# 2                 Venusaur    Grass
# 3    VenusaurMega Venusaur    Grass
# 4               Charmander     Fire
# ..                     ...      ...
# 795                Diancie     Rock
# 796    DiancieMega Diancie     Rock
# 797    HoopaHoopa Confined  Psychic
# 798     HoopaHoopa Unbound  Psychic
# 799              Volcanion     Fire
#
# [800 rows x 2 columns]
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# ...

# %% [markdown]
# # **Sorting/Describing Data**

# %%
df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
df.sort_values('Name')
# Out:
#        #                     Name   Type 1  Type 2  Total   HP  Attack  \
# 510  460                Abomasnow    Grass     Ice    494   90      92
# 511  460  AbomasnowMega Abomasnow    Grass     Ice    594   90     132
# 68    63                     Abra  Psychic     NaN    310   25      20
# 392  359                    Absol     Dark     NaN    465   65     130
# 393  359          AbsolMega Absol     Dark     NaN    565   65     150
# ..   ...                      ...      ...     ...    ...  ...     ...
# 632  571                  Zoroark     Dark     NaN    510   60     105
# 631  570                    Zorua     Dark     NaN    330   40      65
# 46    41                    Zubat   Poison  Flying    245   40      45
# 695  634                 Zweilous     Dark  Dragon    420   72      85
# 794  718         Zygarde50% Forme   Dragon  Ground    600  108     100
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values('Name',ascending=False)
# Out:
#        #                     Name   Type 1  Type 2  Total   HP  Attack  \
# 794  718         Zygarde50% Forme   Dragon  Ground    600  108     100
# 695  634                 Zweilous     Dark  Dragon    420   72      85
# 46    41                    Zubat   Poison  Flying    245   40      45
# 631  570                    Zorua     Dark     NaN    330   40      65
# 632  571                  Zoroark     Dark     NaN    510   60     105
# ..   ...                      ...      ...     ...    ...  ...     ...
# 393  359          AbsolMega Absol     Dark     NaN    565   65     150
# 392  359                    Absol     Dark     NaN    465   65     130
# 68    63                     Abra  Psychic     NaN    310   25      20
# 511  460  AbomasnowMega Abomasnow    Grass     Ice    594   90     132
# 510  460                Abomasnow    Grass     Ice    494   90      92
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# # **Making changes to the data**

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df['Total']=df['Attack']+df['Defense']+df['Sp. Atk']+df['Sp. Def']+df['Speed']
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    273  45      49       49
# 1  2                Ivysaur  Grass  Poison    345  60      62       63
# 2  3               Venusaur  Grass  Poison    445  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    545  80     100      123
# 4  4             Charmander   Fire     NaN    270  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
49+49+65+65+45
# Out:
# 273

# %% [markdown]
# # **Saving our Data(Exporting into Desired Format**

# %%
df.to_csv('modified.csv')

# %%
df.to_excel('modified.xlsx')

# %% [markdown]
# # **Filtering Data**

# %%
df.loc[df['Type 1']=='Grass']
# Out:
#        #                   Name Type 1    Type 2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison    273   45      49       49
# 1      2                Ivysaur  Grass    Poison    345   60      62       63
# 2      3               Venusaur  Grass    Poison    445   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison    545   80     100      123
# 48    43                 Oddish  Grass    Poison    275   45      50       55
# ..   ...                    ...    ...       ...    ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN    257   56      61       65
# 719  651              Quilladin  Grass       NaN    344   61      78       95
# 720  652             Chesnaught  Grass  Fighting    442   88     107      122
# 740  672                 Skiddo  Grass       NaN    284   66      65       48
# 741  673                 Gogoat  Grass       NaN    408  123     100       62
#
# ...

# %%
df.loc[(df['Type 1']=='Grass') & (df['Type 2']=='Poison') & df['HP']>70]
# Out:
# Empty DataFrame
# Columns: [#, Name, Type 1, Type 2, Total, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Generation, Legendary]
# Index: []

# %%
df.loc[df['Name'].str.contains('Mega')]
# Out:
#        #                       Name    Type 1    Type 2  Total   HP  Attack  \
# 3      3      VenusaurMega Venusaur     Grass    Poison    545   80     100
# 7      6  CharizardMega Charizard X      Fire    Dragon    556   78     130
# 8      6  CharizardMega Charizard Y      Fire    Flying    556   78     104
# 12     9    BlastoiseMega Blastoise     Water       NaN    551   79     103
# 19    15      BeedrillMega Beedrill       Bug    Poison    430   65     150
# 23    18        PidgeotMega Pidgeot    Normal    Flying    496   83      80
# 71    65      AlakazamMega Alakazam   Psychic       NaN    535   55      50
# 87    80        SlowbroMega Slowbro     Water   Psychic    495   95      75
# 102   94          GengarMega Gengar     Ghost    Poison    540   60      65
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN    485  105     125
# 137  127          PinsirMega Pinsir       Bug    Flying    535   65     155
# ...

# %%
df.loc[~df['Name'].str.contains('Mega')]
# Out:
#        #                 Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1            Bulbasaur    Grass  Poison    273   45      49       49
# 1      2              Ivysaur    Grass  Poison    345   60      62       63
# 2      3             Venusaur    Grass  Poison    445   80      82       83
# 4      4           Charmander     Fire     NaN    270   39      52       43
# 5      5           Charmeleon     Fire     NaN    347   58      64       58
# ..   ...                  ...      ...     ...    ...  ...     ...      ...
# 794  718     Zygarde50% Forme   Dragon  Ground    492  108     100      121
# 795  719              Diancie     Rock   Fairy    550   50     100      150
# 797  720  HoopaHoopa Confined  Psychic   Ghost    520   80     110       60
# 798  720   HoopaHoopa Unbound  Psychic    Dark    600   80     160       60
# 799  721            Volcanion     Fire   Water    520   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
import re
df.loc[df['Type 1'].str.contains('Fire|Grass',regex=True)]
# Out:
#        #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass  Poison    273   45      49       49
# 1      2                Ivysaur  Grass  Poison    345   60      62       63
# 2      3               Venusaur  Grass  Poison    445   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison    545   80     100      123
# 4      4             Charmander   Fire     NaN    270   39      52       43
# ..   ...                    ...    ...     ...    ...  ...     ...      ...
# 735  667                 Litleo   Fire  Normal    307   62      50       58
# 736  668                 Pyroar   Fire  Normal    421   86      68       72
# 740  672                 Skiddo  Grass     NaN    284   66      65       48
# 741  673                 Gogoat  Grass     NaN    408  123     100       62
# 799  721              Volcanion   Fire   Water    520   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
import re
df.loc[df['Type 1'].str.contains('fire|grass',flags=re.I,regex=True)]
# Out:
#        #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass  Poison    273   45      49       49
# 1      2                Ivysaur  Grass  Poison    345   60      62       63
# 2      3               Venusaur  Grass  Poison    445   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison    545   80     100      123
# 4      4             Charmander   Fire     NaN    270   39      52       43
# ..   ...                    ...    ...     ...    ...  ...     ...      ...
# 735  667                 Litleo   Fire  Normal    307   62      50       58
# 736  668                 Pyroar   Fire  Normal    421   86      68       72
# 740  672                 Skiddo  Grass     NaN    284   66      65       48
# 741  673                 Gogoat  Grass     NaN    408  123     100       62
# 799  721              Volcanion   Fire   Water    520   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
import re
df.loc[df['Name'].str.contains('pi[a-z]*',flags=re.I,regex=True)]
# Out:
#        #                     Name    Type 1    Type 2  Total   HP  Attack  \
# 13    10                 Caterpie       Bug       NaN    150   45      30
# 20    16                   Pidgey    Normal    Flying    211   40      45
# 21    17                Pidgeotto    Normal    Flying    286   63      60
# 22    18                  Pidgeot    Normal    Flying    396   83      80
# 23    18      PidgeotMega Pidgeot    Normal    Flying    496   83      80
# 30    25                  Pikachu  Electric       NaN    285   35      55
# 42    37                   Vulpix      Fire       NaN    261   38      41
# 76    70               Weepinbell     Grass    Poison    325   65      90
# 84    78                 Rapidash      Fire       NaN    435   65     100
# 136  127                   Pinsir       Bug       NaN    435   65     125
# 137  127        PinsirMega Pinsir       Bug    Flying    535   65     155
# 181  167                 Spinarak       Bug    Poison    210   40      60
# ...

# %%
import re
df.loc[df['Name'].str.contains('^pi[a-z]*',flags=re.I,regex=True)]
# Out:
#        #                 Name    Type 1    Type 2  Total   HP  Attack  \
# 20    16               Pidgey    Normal    Flying    211   40      45
# 21    17            Pidgeotto    Normal    Flying    286   63      60
# 22    18              Pidgeot    Normal    Flying    396   83      80
# 23    18  PidgeotMega Pidgeot    Normal    Flying    496   83      80
# 30    25              Pikachu  Electric       NaN    285   35      55
# 136  127               Pinsir       Bug       NaN    435   65     125
# 137  127    PinsirMega Pinsir       Bug    Flying    535   65     155
# 186  172                Pichu  Electric       NaN    185   20      40
# 219  204               Pineco       Bug       NaN    240   50      65
# 239  221            Piloswine       Ice    Ground    350  100     100
# 438  393               Piplup     Water       NaN    261   53      51
# 558  499              Pignite      Fire  Fighting    328   90      93
# ...

# %% [markdown]
# # **Conditional Changes**

# %%
df.loc[df['Type 1']=='Fire','Type 1']='Flamer'  #fire changed to flamer
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    273  45      49       49
# 1      2                Ivysaur    Grass  Poison    345  60      62       63
# 2      3               Venusaur    Grass  Poison    445  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    545  80     100      123
# 4      4             Charmander   Flamer     NaN    270  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    550  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    650  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    520  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    600  80     160       60
# 799  721              Volcanion   Flamer   Water    520  80     110      120
#
# ...

# %%
df.loc[df['Type 1']=='Flamer','Type 1']='Fire'  #again flamer changed to fire
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    273  45      49       49
# 1      2                Ivysaur    Grass  Poison    345  60      62       63
# 2      3               Venusaur    Grass  Poison    445  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    545  80     100      123
# 4      4             Charmander     Fire     NaN    270  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    550  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    650  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    520  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    600  80     160       60
# 799  721              Volcanion     Fire   Water    520  80     110      120
#
# ...

# %%
df.loc[df['Type 1']=='Fire','Legendary']=True
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    273  45      49       49
# 1      2                Ivysaur    Grass  Poison    345  60      62       63
# 2      3               Venusaur    Grass  Poison    445  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    545  80     100      123
# 4      4             Charmander     Fire     NaN    270  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    550  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    650  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    520  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    600  80     160       60
# 799  721              Volcanion     Fire   Water    520  80     110      120
#
# ...

# %%
df.loc[df['Total']>500,['Generation','Legendary']]='TEST VALUE'
df
# Out:
# <ipython-input-53-25ec0110cb90>:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'TEST VALUE' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[df['Total']>500,['Generation','Legendary']]='TEST VALUE'
# <ipython-input-53-25ec0110cb90>:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'TEST VALUE' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   df.loc[df['Total']>500,['Generation','Legendary']]='TEST VALUE'
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    273  45      49       49
# 1      2                Ivysaur    Grass  Poison    345  60      62       63
# 2      3               Venusaur    Grass  Poison    445  80      82       83
# ...

# %%
df.loc[df['Total']>500,['Generation','Legendary']]=['TEST 1','TEST 2']
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    273  45      49       49
# 1      2                Ivysaur    Grass  Poison    345  60      62       63
# 2      3               Venusaur    Grass  Poison    445  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    545  80     100      123
# 4      4             Charmander     Fire     NaN    270  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    550  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    650  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    520  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    600  80     160       60
# 799  721              Volcanion     Fire   Water    520  80     110      120
#
# ...

# %% [markdown]
# # **Aggregate Statistics(Groupby)**

# %%
df.groupby(['Type 1']).sum()
# Out:
#           Unnamed: 0      #  \
# Type 1
# Bug            25397  23080
# Dark           15729  14302
# Dragon         16699  15180
# Electric       17626  15994
# Fairy           8407   7642
# Fighting       10812   9824
# Fire           18769  17025
# Flying          2986   2711
# Ghost          17161  15568
# Grass          26629  24141
# Ground         12554  11401
# Ice            11176  10165
# Normal         34455  31279
# Poison          7792   7050
# Psychic        23946  21706
# Rock           19001  17280
# Steel          13130  11957
# Water          37331  33946
#
#                                                        Name  \
# Type 1
# Bug       CaterpieMetapodButterfreeWeedleKakunaBeedrillB...
# Dark      UmbreonMurkrowSneaselHoundourHoundoomHoundoomM...
# Dragon    DratiniDragonairDragoniteAltariaAltariaMega Al...
# Electric  PikachuRaichuMagnemiteMagnetonVoltorbElectrode...
# Fairy     ClefairyClefableCleffaTogepiTogeticSnubbullGra...
# ...

# %%
df.groupby(['Type 1']).count()
# Out:
#           Unnamed: 0    #  Name  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Type 1
# Bug               69   69    69      52     69   69      69       69       69
# Dark              31   31    31      21     31   31      31       31       31
# Dragon            32   32    32      21     32   32      32       32       32
# Electric          44   44    44      17     44   44      44       44       44
# Fairy             17   17    17       2     17   17      17       17       17
# Fighting          27   27    27       7     27   27      27       27       27
# Fire              52   52    52      24     52   52      52       52       52
# Flying             4    4     4       2      4    4       4        4        4
# Ghost             32   32    32      22     32   32      32       32       32
# Grass             70   70    70      37     70   70      70       70       70
# Ground            32   32    32      19     32   32      32       32       32
# ...

# %%
df['count']=1
df.groupby(['Type 1']).count()['count']
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: count, dtype: int64

# %%
df['count']=1
df.groupby(['Type 1','Type 2']).count()['count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64

# %% [markdown]
# # **Working with large amounts of data**

# %%
for df in pd.read_csv('modified.csv',chunksize=5):
  print("CHUNK DF")
  print(df)
# Out:
# CHUNK DF
#    Unnamed: 0  #                   Name Type 1  Type 2  Total  HP  Attack  \
# 0           0  1              Bulbasaur  Grass  Poison    273  45      49
# 1           1  2                Ivysaur  Grass  Poison    345  60      62
# 2           2  3               Venusaur  Grass  Poison    445  80      82
# 3           3  3  VenusaurMega Venusaur  Grass  Poison    545  80     100
# 4           4  4             Charmander   Fire     NaN    270  39      52
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       49       65       65     45           1      False
# 1       63       80       80     60           1      False
# 2       83      100      100     80           1      False
# 3      123      122      120     80           1      False
# 4       43       60       50     65           1      False
# CHUNK DF
#    Unnamed: 0  #                       Name Type 1  Type 2  Total  HP  Attack  \
# ...

# %%
new_df=pd.DataFrame(columns=df.columns)
for df in pd.read_csv('modified.csv',chunksize=5):
  results=df.groupby(['Type 1']).count()
  new_df=pd.concat([new_df,results])
new_df
# Out:
#         Unnamed: 0  # Name Type 1 Type 2 Total HP Attack Defense Sp. Atk  \
# Fire             1  1    1    NaN      0     1  1      1       1       1
# Grass            4  4    4    NaN      4     4  4      4       4       4
# Fire             4  4    4    NaN      3     4  4      4       4       4
# Water            1  1    1    NaN      0     1  1      1       1       1
# Bug              2  2    2    NaN      0     2  2      2       2       2
# ...            ... ..  ...    ...    ...   ... ..    ...     ...     ...
# Fairy            1  1    1    NaN      0     1  1      1       1       1
# Flying           2  2    2    NaN      2     2  2      2       2       2
# Fire             1  1    1    NaN      1     1  1      1       1       1
# Psychic          2  2    2    NaN      2     2  2      2       2       2
# Rock             2  2    2    NaN      2     2  2      2       2       2
#
#         Sp. Def Speed Generation Legendary
# Fire          1     1          1         1
# ...
